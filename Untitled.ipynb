# %% [markdown]
# # McDonald's menu nutrition EDA
#
#
#
#
# ### Background
#
# McDonald's is one the world's most popular fast food chain, spanning across 114 countries with 37,376 outlets. Every menu item on the US menu including breakfast, beef burgers, chicken and fish sandwiches, fries, salads, drinks, coffee and tea, milkshakes, and desserts, has its nutrition information (as of 2017) analyzed in this dataset.

# %%
#Importing essesntial tools 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('menu.csv')

# %%
df.head(5)
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
max_values = df[['Serving Size','Calories','Total Fat','Carbohydrates','Dietary Fiber','Sugars','Protein','Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)']].max()

# %%
max_values
# Out:
# Serving Size                 9.6 oz (272 g)
# Calories                               1880
# Total Fat                             118.0
# Carbohydrates                           141
# Dietary Fiber                             7
# Sugars                                  128
# Protein                                  87
# Vitamin A (% Daily Value)               170
# Vitamin C (% Daily Value)               240
# Calcium (% Daily Value)                  70
# Iron (% Daily Value)                     40
# dtype: object

# %% [markdown]
# According to the dataset, the maximum value for calories and some other variables seems to be high. We will try to figure out which menu items these values correspond to but first we will check to see if infact there is any correlation between calories and other independent variables by plotting a correlation matrix next.

# %%
f = plt.figure(figsize=(19,15))
plt.matshow(df.corr(),fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# * The correlation coefficients are proportionate to the box's size and colour intensity.
# * As we can see, the variable Calories has strong obvious correlations of the other independent variables whether they are positive or negative.

# %%
sns.boxplot(x=df['Calories'],y=df['Category'],hue=df['Category'],palette= 'Set2')
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='Category'>

# %% [markdown]
# From the above boxplot, we notice quite a number of outliers.

# %% [markdown]
# **Now lets figure out which exact item contains high calories in the category**

# %%
plot = sns.set_style('whitegrid')
ax = sns.boxplot(x=df["Calories"])

# %%
df["Calories"].idxmax()
# Out:
# 82

# %%
df.at[82,'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %% [markdown]
# Chicken McNuggets is the answer here. We will now perform the same fact finding process for other categories and items.

# %%
#Sodium vs Category
plot = sns.stripplot(x='Category', y='Sodium', data=df)
plt.setp(plot.get_xticklabels(),rotation=70)
plt.title('Sodium Content')
plt.show()


#Protein vs total fat
plot = sns.jointplot(x='Protein', y='Total Fat', data=df)

# Calories vs Protein
plot = sns.jointplot(x='Protein', y='Calories', data=df)


# Calories vs Carbohydrates
plot = sns.jointplot(x='Carbohydrates', y='Calories', data=df)

# Calories vs Cholesterol
plot = sns.jointplot(x='Cholesterol', y='Calories', data=df)

# Calories vs total fat
plot = sns.jointplot(x='Total Fat', y='Calories', data=df)

# Calories vs Sugars
plot = sns.jointplot(x='Sugars', y='Calories', data=df)

# Calories vs Dietary Fiber
plot=sns.jointplot(x="Dietary Fiber", y='Calories', data=df)

# Calories vs Trans Fat
plot=sns.jointplot(x="Trans Fat", y='Calories', data=df)

# Calories vs Vitamin A
plot=sns.jointplot(x="Vitamin A (% Daily Value)", y='Calories', data=df)

# Calories vs Calcium
plot=sns.jointplot(x="Calcium (% Daily Value)", y='Calories', data=df)

# Calories vs Iron
plot=sns.jointplot(x="Iron (% Daily Value)", y='Calories', data=df)

# %%
df.at[df['Sodium'].idxmax(),'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
df.at[df['Total Fat'].idxmax(),'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
df.at[df['Protein'].idxmax(),'Item']
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
df.at[df['Carbohydrates'].idxmax(),'Item']
# Out:
# 'Chocolate Shake (Large)'

# %%
df.at[df['Cholesterol'].idxmax(),'Item']
# Out:
# 'Big Breakfast with Hotcakes (Regular Biscuit)'

# %%
df.at[df['Sugars'].idxmax(),'Item']
# Out:
# 'McFlurry with M&M’s Candies (Medium)'

# %%
df.at[df['Trans Fat'].idxmax(),'Item']
# Out:
# 'Double Quarter Pounder with Cheese'

# %%
df.at[df['Dietary Fiber'].idxmax(),'Item']
# Out:
# 'Big Breakfast with Hotcakes (Large Biscuit)'

# %%
df.at[df['Vitamin A (% Daily Value)'].idxmax(),'Item']
# Out:
# 'Premium Bacon Ranch Salad (without Chicken)'

# %%
df.at[df['Calcium (% Daily Value)'].idxmax(),'Item']
# Out:
# 'Strawberry Shake (Large)'

# %%
df.at[df['Iron (% Daily Value)'].idxmax(),'Item']
# Out:
# 'Big Breakfast with Hotcakes (Regular Biscuit)'

# %% [markdown]
# #### As ranked by calories using unique category and item with high calories
#
# * Chicken & Fish: Chicken McNuggets (40 piece) - **1880kcal
# * Breakfast: Big Breakfast with Hotcakes (Large Biscuit) - **1150kcal
# * Smoothies & Shakes: McFlurry with M&M’s Candies (Medium) - **930kcal
# * Beef & Pork: Double Quarter Pounder with Cheese - **750kcal
# * Snacks & Sides: Large French Fries - **510kcal
# * Desserts: Hot Caramel Sundae - **340kcal
# * Beverages: Minute Maid Orange Juice (Large) - **280kcal

# %%
lists = ["Chicken & Fish","Breakfast","Smoothies & Shakes","Beef & Pork","Snacks & Sides","Desserts","Beverages"]

# %%
for list in lists:
    items = df.query('Category == list').sort_values(by='Calories',ascending=False)
    items_custom = items.iloc[:,[1,3,5]]
    
    items_t=df.query('Category == list').sort_values(by="Calories", ascending=True)
    items_custom_t=items_t.iloc[:,[1,3,5]]
    
    print(lists.index(list)+1,".",list)
    
    p_express = px.scatter(items_custom, x="Total Fat",y='Calories', color="Item",size='Calories',template="plotly_dark",hover_name="Item")
    p_express.show()
    
    table = items_custom.iloc[:,[0,1]].sort_values(by='Calories',ascending=False).style.hide_index()
    display(table)
    
    fig,ax=plt.subplots()
    x = items_custom_t.iloc[:,0]
    y = items_custom_t.iloc[:,1]
    ax.barh(x,y, tick_label=x)
    plt.show()
# Out:
# 1 . Chicken & Fish
# ...

# %% [markdown]
# ## Conclusion
#
# * According to FDA, the recommended adult limit for sodium intake should be less than 2,300 milligrams/day - that's equal to about 1 teaspoon of table salt.
#
# * FDA also recommends adults consume 50 grams of protein per day.
#
# * USDA recommends 66-97 grams of fat per day in a 2000 and 2500 calorie diet respectively.
#
# * NHS recommends daily calorie intake of 2000 kcal for women and 2500 kcal for men.
#
# ### Chicken McNuggets was found to contain high amounts of sodium (3600 milligrams), protein (87 grams), total fat (118 grams) and calories (1880 kcal).
